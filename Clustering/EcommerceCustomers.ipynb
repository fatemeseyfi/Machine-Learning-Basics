# %%
import pandas as pd
import numpy as np
# Out:
# C:\Users\wq\AppData\Local\Temp\ipykernel_13468\2162656668.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv('EcommerceCustomers.csv')
df2 = pd.read_excel('Bargainnumeric.xlsx')
df3 = pd.read_excel('CRMclean.xlsx', sheet_name='Sheet1')
# Out:
# C:\Users\wq\AppData\Roaming\Python\Python310\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)

# %%
df3
# Out:
#          Q1      Q2                Q3     Q4         Q5         Q6  Q7  Q8  \
# 0     Smith  288389        Consulting   8790 2023-03-01  Contacted  25  46
# 1     Smith  287515        Consulting   9252 2023-03-01       Demo  32  44
# 2    Garcia  388664  Info and Culture  12723 2023-03-02  Contacted  35  45
# 3      Chen  281026        Consulting   9740 2023-03-02  Contacted  35  30
# 4     Smith  354030         Ecommerce  13563 2023-03-02   Proposal  47  42
# ..      ...     ...               ...    ...        ...        ...  ..  ..
# 130    Zhao  393365  Info and Culture  18870 2023-03-29  Contacted  38  42
# 131  Garcia  388480  Info and Culture  15911 2023-03-29  Contacted  41  46
# 132    Devi  465745            Trades  15983 2023-03-29  Contacted  45  37
# 133  Taylor  474051            Trades  16184 2023-03-29  Contacted  30  45
# 134    Zhao  394891  Info and Culture  11099 2023-03-30  Contacted  41  43
#
#       Q9  Q10  ...        Q25           Q26   Q27   Q28  Q29   Q30  Q31  \
# 0    0.8   35  ... 2023-05-03     Contacted  30.0  46.0  0.9  35.0  2.0
# 1    0.9   55  ... 2023-05-07          Demo  40.0  42.0  1.2  55.0  5.0
# 2    1.5   50  ... 2023-05-05     Contacted  50.0  46.0  1.4  69.0  7.0
# 3    0.5   65  ... 2023-05-06          Demo  30.0  37.0  1.5  50.0  4.0
# 4    1.1   60  ... 2023-05-09  Negotiations  45.0  41.0  1.3  42.0  4.0
# ..   ...  ...  ...        ...           ...   ...   ...  ...   ...  ...
# 130  1.2   45  ... 2023-05-21          Demo  42.0  38.0  1.1  53.0  5.0
# 131  1.0   47  ... 2023-05-30     Contacted  38.0  42.0  0.9  42.0  3.0
# 132  0.9   60  ... 2023-05-22      Proposal  45.0  39.0  1.2  56.0  5.0
# 133  0.8   38  ... 2023-05-29     Contacted  33.0  45.0  1.0  40.0  3.0
# 134  1.3   43  ... 2023-05-22      Proposal  30.0  37.0  1.8  41.0  3.0
#
#           Q32            Q33    Q34
# 0    Neutral         Average  Email
# 1    Positive      Very Good  Phone
# 2    Neutral   At Churn Risk  Email
# 3    Positive           Good  Email
# 4    Positive           Good  Phone
# ..        ...            ...    ...
# 130  Positive           Good  Phone
# 131  Neutral         Average  Phone
# 132  Positive           Good  Phone
# 133  Neutral         Average  Email
# 134  Neutral   At Churn Risk  Email
#
# [135 rows x 34 columns]

# %%
from seaborn import scatterplot
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rcParams['lines.markersize'] = 10

scatterplot(x = df3["Q4"], y = df3['Q2'])
plt.xlabel('Projected Value of Contracts')
plt.ylabel('Company Revenue')
plt.show()

# %%
from sklearn.cluster import KMeans

# %%
x = np.array(df3[['Q4', 'Q2']])
x
# Out:
# array([[  8790, 288389],
#        [  9252, 287515],
#        [ 12723, 388664],
#        [  9740, 281026],
#        [ 13563, 354030],
#        [ 14992, 340157],
#        [ 17144, 612319],
#        [  9989, 292403],
#        [ 12712, 339087],
#        [  8028, 284854],
#        [  9417, 283414],
#        [  8734, 289603],
#        [ 14787, 343434],
#        [ 14371, 354127],
#        [ 15868, 361269],
#        [ 15946, 391375],
#        [  8005, 291645],
#        [  7838, 293033],
#        [  9301, 289404],
#        [  9048, 279830],
#        [ 16592, 353519],
#        [ 11975, 359005],
#        [  7478, 286898],
#        [  8079, 291497],
#        [  7800, 284809],
#        [  9881, 286607],
#        [  9479, 284851],
#        [  8083, 292032],
#        [ 15275, 369083],
#        [ 13918, 354223],
#        [ 16361, 358252],
#        [ 12530, 349009],
#        [ 16312, 391491],
#        [ 14127, 354197],
#        [ 14743, 351771],
#        [ 12794, 367535],
#        [ 14611, 608085],
#        [ 11910, 367205],
#        [ 15420, 349020],
#        [ 10905, 353342],
#        [ 14604, 350569],
#        [ 13674, 357902],
#        [ 15662, 363925],
#        [ 11327, 357759],
#        [ 13993, 625958],
#        [ 16753, 367411],
#        [ 17791, 473124],
#        [ 12402, 382167],
#        [ 14767, 398100],
#        [ 17381, 360329],
#        [ 16799, 349827],
#        [ 15431, 360020],
#        [ 16805, 361017],
#        [ 15455, 616015],
#        [ 17241, 355049],
#        [  8530, 287237],
#        [ 15232, 351249],
#        [ 10366, 355896],
#        [  9798, 280553],
#        [ 15430, 476964],
#        [ 16601, 450978],
#        [ 17722, 390749],
#        [ 16779, 387324],
#        [ 17303, 358218],
#        [ 15032, 395433],
#        [ 18919, 350907],
#        [  7943, 294620],
#        [ 13735, 370754],
#        [ 16043, 363489],
#        [  8375, 282172],
#        [ 17599, 465569],
#        [ 15552, 600214],
#        [ 17493, 606021],
#        [ 17476, 367616],
#        [ 15117, 354636],
#        [ 12755, 355035],
#        [ 16352, 476182],
#        [ 16232, 384338],
#        [ 15161, 622861],
#        [ 13546, 395773],
#        [  7827, 288560],
#        [  8472, 281353],
#        [ 15257, 382188],
#        [ 15309, 617891],
#        [ 15379, 623301],
#        [ 15491, 616810],
#        [ 17133, 334970],
#        [ 16831, 359287],
#        [  8304, 279880],
#        [  9666, 290019],
#        [ 13187, 621637],
#        [ 14092, 410490],
#        [ 17509, 467259],
#        [ 17085, 392315],
#        [ 17498, 609603],
#        [ 11598, 479251],
#        [  7922, 297362],
#        [ 14299, 609876],
#        [ 15280, 614868],
#        [ 15445, 609221],
#        [ 15128, 387661],
#        [ 17838, 610647],
#        [ 14647, 345146],
#        [ 17397, 395530],
#        [ 11631, 351820],
#        [ 14203, 386895],
#        [ 18043, 393845],
#        [ 16395, 597793],
#        [ 16296, 398631],
#        [ 13990, 394935],
#        [ 15211, 469581],
#        [ 15138, 388934],
#        [ 12567, 615165],
#        [ 19379, 387795],
#        [ 13938, 616658],
#        [ 16141, 383447],
#        [ 12927, 382830],
#        [ 14302, 349081],
#        [ 18820, 340029],
#        [ 12248, 473718],
#        [ 14288, 610986],
#        [ 16027, 595505],
#        [ 15131, 360820],
#        [ 12640, 464250],
#        [ 14877, 467087],
#        [ 15964, 606147],
#        [ 16473, 392317],
#        [ 16243, 399179],
#        [ 16350, 466983],
#        [ 13025, 345609],
#        [ 18870, 393365],
#        [ 15911, 388480],
#        [ 15983, 465745],
#        [ 16184, 474051],
#        [ 11099, 394891]], dtype=int64)

# %%
km = KMeans(n_clusters=6)
clusters = km.fit(x)

# %%
labels = km.labels_
labels
# Out:
# array([3, 3, 4, 3, 5, 0, 1, 3, 0, 3, 3, 3, 0, 5, 5, 4, 3, 3, 3, 3, 5, 5,
#        3, 3, 3, 3, 3, 3, 5, 5, 5, 0, 4, 5, 0, 5, 1, 5, 0, 0, 0, 5, 5, 5,
#        1, 5, 2, 4, 4, 5, 0, 5, 5, 1, 5, 3, 0, 5, 3, 2, 2, 4, 4, 5, 4, 0,
#        3, 5, 5, 3, 2, 1, 1, 5, 5, 5, 2, 4, 1, 4, 3, 3, 4, 1, 1, 1, 0, 5,
#        3, 3, 1, 4, 2, 4, 1, 2, 3, 1, 1, 1, 4, 1, 0, 4, 0, 4, 4, 1, 4, 4,
#        2, 4, 1, 4, 1, 4, 4, 0, 0, 2, 1, 1, 5, 2, 2, 1, 4, 4, 2, 0, 4, 4,
#        2, 2, 4])

# %%
from seaborn import scatterplot
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rcParams['lines.markersize'] = 10

scatterplot(x = df3['Q4'], y = df3['Q2'], hue = labels, palette = 'deep')
plt.xlabel('Projected Value of Contracts')
plt.ylabel('Company Revenue')
plt.show()

# %%
wcss = []

k_rng = range(1,10)

for k in k_rng:
  km = KMeans(n_clusters=k)
  km.fit(x)
  wcss.append(km.inertia_)

plt.plot(k_rng, wcss, marker = 'o')
plt.xlabel('Number of clusters (k)')
plt.ylabel('WCSS')
plt.title('Elbow Method')
plt.show()

# %% [markdown]
# Elbow method suggests 4 clusters

# %%
km = KMeans(n_clusters=4)
clusters = km.fit(x)
labels = km.labels_

# %%
scatterplot(x = df3['Q4'], y = df3['Q2'], hue = labels, palette = 'deep')
scatterplot(x = km.cluster_centers_[:,0], y = km.cluster_centers_[:,1], marker = '*', color = 'black')
plt.xlabel('Projected Value of Contracts')
plt.ylabel('Company Revenue')
plt.show()

# %% [markdown]
# Silhouette Coefficent:
# 1. Looks at how far data points are from other clusters.
# 2. if the silhouette score is closed to 0, then there are no meaningful clusters, the cluster score is to 1. the more clusters are different from each other, if the cluster score is closed to -1 then data points are assigned to the wrong clusters.

# %%
from sklearn.metrics import silhouette_score, silhouette_samples
#https://medium.com/@Suraj_Yadav/silhouette-coefficient-explained-with-a-practical-example-assessing-cluster-fit-c0bb3fdef719

# %%
sil_score = silhouette_score(x, labels)
sil_score
# Out:
# 0.792207331319125

# %%
k_rng = range(2,11)
s_score = []

for k in k_rng:
  km = KMeans(n_clusters=k)
  km.fit(x)
  labels = km.labels_
  s_score.append(silhouette_score(x, labels))

print(s_score)
plt.plot(k_rng, s_score, marker = 'o')
plt.xlabel('Number of clusters (k)')
plt.ylabel('Silhouette Score')
plt.show()
# Out:
# [0.7239691941949178, 0.661596208250213, 0.792207331319125, 0.8164224311304203, 0.7491700212778134, 0.6616443719585738, 0.6425075637202038, 0.6000701497693787, 0.6033083095983997]

# %% [markdown]
# Silhouette Score suggests 5 clusters

# %%
km = KMeans(n_clusters=5)
clusters = km.fit(x)
labels = km.labels_

scatterplot(x = df3['Q4'], y = df3['Q2'], hue = labels, palette = 'deep')
scatterplot(x = km.cluster_centers_[:,0], y = km.cluster_centers_[:,1], marker = '*', color = 'black')
plt.xlabel('Projected Value of Contracts')
plt.ylabel('Company Revenue')
plt.show()

# %% [markdown]
# Calinski Harabasz
# 1. A higher score indicates the clusters are well separated from each other
# 2. Tends to favor models with more clusters

# %%
from sklearn.metrics import calinski_harabasz_score
# https://www.geeksforgeeks.org/calinski-harabasz-index-cluster-validity-indices-set-3/

# %%
ch_score = calinski_harabasz_score(x, labels)
ch_score
# Out:
# 6727.416721903632

# %%
k_rng = range(2,11)
ch_score = []

for k in k_rng:
  km = KMeans(n_clusters=k)
  km.fit(x)
  labels = km.labels_
  ch_score.append(silhouette_score(x, labels))

plt.plot(k_rng, ch_score, marker = 'o')
plt.xlabel('Number of clusters (k)')
plt.ylabel('Silhouette Score')
plt.show()
# Out:
# [0.7239691941949178, 0.661596208250213, 0.792207331319125, 0.8164224311304203, 0.7491700212778134, 0.6616443719585738, 0.6425075637202038, 0.6000701497693787, 0.6033083095983997]

# %% [markdown]
# Calinski Harabasz also suggests 5 clusters

# %% [markdown]
# Davies Bouldin Score

# %%
from sklearn.metrics import davies_bouldin_score

# %%
davies_bouldin_score(x, labels)
# Out:
# 0.4889270842216618

# %%
k_rng = range(2,11)
db_score = []

for k in k_rng:
  km = KMeans(n_clusters=k)
  km.fit(x)
  labels = km.labels_
  db_score.append(silhouette_score(x, labels))

plt.plot(k_rng, db_score, marker = 'o')
plt.xlabel('Number oDavies Bouldin Scoref clusters (k)')
plt.ylabel('')
plt.show()

# %% [markdown]
# Davies Bouldin Score also suggests 5 clusters

# %%
import time
import warnings
from itertools import cycle, islice

import matplotlib.pyplot as plt
import numpy as np

from sklearn import cluster, datasets
from sklearn.preprocessing import StandardScaler

# %%
n_samples = 1500
noisy_circles = datasets.make_circles(
    n_samples=n_samples, factor=0.5, noise=0.05, random_state=170
)
noisy_moons = datasets.make_moons(n_samples=n_samples, noise=0.05, random_state=170)
blobs = datasets.make_blobs(n_samples=n_samples, random_state=170)
rng = np.random.RandomState(170)
no_structure = rng.rand(n_samples, 2), None

# Anisotropicly distributed data
X, y = datasets.make_blobs(n_samples=n_samples, random_state=170)
transformation = [[0.6, -0.6], [-0.4, 0.8]]
X_aniso = np.dot(X, transformation)
aniso = (X_aniso, y)

# blobs with varied variances
varied = datasets.make_blobs(
    n_samples=n_samples, cluster_std=[1.0, 2.5, 0.5], random_state=170
)

# %%
# Set up cluster parameters
plt.figure(figsize=(9 * 1.3 + 2, 14.5))
plt.subplots_adjust(
    left=0.02, right=0.98, bottom=0.001, top=0.96, wspace=0.05, hspace=0.01
)

plot_num = 1

default_base = {"n_neighbors": 10, "n_clusters": 3}

datasets = [
    (noisy_circles, {"n_clusters": 2}),
    (noisy_moons, {"n_clusters": 2}),
    (varied, {"n_neighbors": 2}),
    (aniso, {"n_neighbors": 2}),
    (blobs, {}),
    (no_structure, {}),
]

for i_dataset, (dataset, algo_params) in enumerate(datasets):
    # update parameters with dataset-specific values
    params = default_base.copy()
    params.update(algo_params)

    X, y = dataset

    # normalize dataset for easier parameter selection
    X = StandardScaler().fit_transform(X)

    # ============
    # Create cluster objects
    # ============
    ward = cluster.AgglomerativeClustering(
        n_clusters=params["n_clusters"], linkage="ward"
    )
    complete = cluster.AgglomerativeClustering(
        n_clusters=params["n_clusters"], linkage="complete"
    )
    average = cluster.AgglomerativeClustering(
        n_clusters=params["n_clusters"], linkage="average"
    )
    single = cluster.AgglomerativeClustering(
        n_clusters=params["n_clusters"], linkage="single"
    )

    clustering_algorithms = (
        ("Single Linkage", single),
        ("Average Linkage", average),
        ("Complete Linkage", complete),
        ("Ward Linkage", ward),
    )

    for name, algorithm in clustering_algorithms:
        t0 = time.time()

        # catch warnings related to kneighbors_graph
        with warnings.catch_warnings():
            warnings.filterwarnings(
                "ignore",
                message="the number of connected components of the "
                + "connectivity matrix is [0-9]{1,2}"
                + " > 1. Completing it to avoid stopping the tree early.",
                category=UserWarning,
            )
            algorithm.fit(X)

        t1 = time.time()
        if hasattr(algorithm, "labels_"):
            y_pred = algorithm.labels_.astype(int)
        else:
            y_pred = algorithm.predict(X)

        plt.subplot(len(datasets), len(clustering_algorithms), plot_num)
        if i_dataset == 0:
            plt.title(name, size=18)

        colors = np.array(
            list(
                islice(
                    cycle(
                        [
                            "#377eb8",
                            "#ff7f00",
                            "#4daf4a",
                            "#f781bf",
                            "#a65628",
                            "#984ea3",
                            "#999999",
                            "#e41a1c",
                            "#dede00",
                        ]
                    ),
                    int(max(y_pred) + 1),
                )
            )
        )
        plt.scatter(X[:, 0], X[:, 1], s=10, color=colors[y_pred])

        plt.xlim(-2.5, 2.5)
        plt.ylim(-2.5, 2.5)
        plt.xticks(())
        plt.yticks(())
        plt.text(
            0.99,
            0.01,
            ("%.2fs" % (t1 - t0)).lstrip("0"),
            transform=plt.gca().transAxes,
            size=15,
            horizontalalignment="right",
        )
        plot_num += 1

plt.show()
