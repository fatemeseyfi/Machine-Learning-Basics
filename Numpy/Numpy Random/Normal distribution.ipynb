# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x = random.normal(size=(2,3))
x
# Out:
# array([[-0.70700864,  0.00233132, -0.9014692 ],
#        [ 0.59113377, -0.20726007, -0.92438658]])

# %%
y = random.normal(loc=1, scale=2, size=(2,3))
y
# Out:
# array([[ 0.73584914, -1.7452214 ,  0.13823802],
#        [ 3.67125196,  5.06621534, -4.37710416]])

# %%
sns.distplot(y, hist=False)
plt.show()
# Out:
# C:\Users\wq\AppData\Local\Temp\ipykernel_3936\303246848.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y, hist=False)

# %%
# The curve of a Normal Distribution is also known as the Bell Curve because of the bell-shaped curve.
sns.distplot(random.normal(size=1000), hist=False)
plt.show()
# Out:
# C:\Users\wq\AppData\Local\Temp\ipykernel_3936\2641618968.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(size=1000), hist=False)

# %%
# Out:
# C:\Users\wq\AppData\Local\Temp\ipykernel_3936\303246848.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y, hist=False)
