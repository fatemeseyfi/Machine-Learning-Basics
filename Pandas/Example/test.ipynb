# %% [markdown]
# # My First Notebook

# %%
import pandas as pd
# Out:
# C:\Users\wq\AppData\Local\Temp\ipykernel_15088\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
na_vals = ['NA', 'Missing']
data_frame = pd.read_csv('Data/survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv('Data/survey_results_schema.csv', index_col = 'Column')

# %%
data_frame
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
# get first 5 rows:
data_frame.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
# get first 10 rows:
data_frame.head(10)
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# 6           I am not primarily a developer, but I write co...      Yes
# 7                              I am a developer by profession       No
# 8                                 I code primarily as a hobby      Yes
# 9                              I am a developer by profession      Yes
# 10                             I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# ...

# %%
# get last 10 rows:
data_frame.tail(10)
# Out:
#            MainBranch Hobbyist  \
# Respondent
# 88062             NaN       No
# 88076             NaN       No
# 88182             NaN      Yes
# 88212             NaN       No
# 88282             NaN      Yes
# 88377             NaN      Yes
# 88601             NaN       No
# 88802             NaN       No
# 88816             NaN       No
# 88863             NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 88062                                                   Never
# 88076                                                   Never
# 88182                              Once a month or more often
# 88212                                 Less than once per year
# 88282                              Once a month or more often
# 88377       Less than once a month but more than once per ...
# 88601                                                   Never
# 88802                                                   Never
# ...

# %%
data_frame.shape
# Out:
# (88883, 84)

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 88883 entries, 1 to 88863
# Data columns (total 84 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   MainBranch              88331 non-null  object
#  1   Hobbyist                88883 non-null  object
#  2   OpenSourcer             88883 non-null  object
#  3   OpenSource              86842 non-null  object
#  4   Employment              87181 non-null  object
#  5   Country                 88751 non-null  object
#  6   Student                 87014 non-null  object
#  7   EdLevel                 86390 non-null  object
#  8   UndergradMajor          75614 non-null  object
#  9   EduOther                84260 non-null  object
#  10  OrgSize                 71791 non-null  object
#  11  DevType                 81335 non-null  object
#  12  YearsCode               87938 non-null  object
#  13  Age1stCode              87634 non-null  object
# ...

# %%
# display all of rows and columns:
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
# display schema:
schema_df
# Out:
#                                                              QuestionText
# Column
# Respondent              Randomized respondent ID number (not in order ...
# MainBranch              Which of the following options best describes ...
# Hobbyist                                          Do you code as a hobby?
# OpenSourcer                   How often do you contribute to open source?
# OpenSource              How do you feel about the quality of open sour...
# Employment              Which of the following best describes your cur...
# Country                         In which country do you currently reside?
# Student                 Are you currently enrolled in a formal, degree...
# EdLevel                 Which of the following best describes the high...
# UndergradMajor          What was your main or most important field of ...
# EduOther                Which of the following types of non-degree edu...
# OrgSize                 Approximately how many people are employed by ...
# ...

# %%
# show name of columns
data_frame.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
data_frame['Hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4         No
# 5        Yes
#         ...
# 88377    Yes
# 88601     No
# 88802     No
# 88816     No
# 88863    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
# how many of them are "yes" and how many are "no"
data_frame['Hobbyist'].value_counts()
# Out:
# Hobbyist
# Yes    71257
# No     17626
# Name: count, dtype: int64

# %%
# first row and hobbyist
data_frame.loc[1, 'Hobbyist']
# Out:
# 'Yes'

# %%
# first 3 rows and hobbyist
data_frame.loc[[1,2,3], 'Hobbyist']
data_frame.loc[1:3, 'Hobbyist']
# Out:
# Respondent
# 1    Yes
# 2     No
# 3    Yes
# Name: Hobbyist, dtype: object

# %%
data_frame.loc[1:3, 'Hobbyist':'Employment']
# Out:
#            Hobbyist              OpenSourcer  \
# Respondent
# 1               Yes                    Never
# 2                No  Less than once per year
# 3               Yes                    Never
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
#
#                                         Employment
# Respondent
# 1           Not employed, and not looking for work
# 2               Not employed, but looking for work
# 3                               Employed full-time

# %%
data_frame.loc[1,'Employment']
# Out:
# 'Not employed, and not looking for work'

# %%
# search with specific label and column
schema_df.loc['MgrIdiot', 'QuestionText']
# Out:
# 'How confident are you that your manager knows what they’re doing?'

# %% [markdown]
# Indexes: How to Set, Reset, and Use Indexes

# %%
#sort reverse index
schema_df.sort_index(ascending = False)
# Out:
#                                                              QuestionText
# Column
# YearsCodePro            How many years have you coded professionally (...
# YearsCode               Including any education, how many years have y...
# WorkWeekHrs              On average, how many hours per week do you work?
# WorkRemote                                How often do you work remotely?
# WorkPlan                          How structured or planned is your work?
# WorkLoc                                   Where would you prefer to work?
# WorkChallenge           Of these options, what are your greatest chall...
# WelcomeChange           Compared to last year, how welcome do you feel...
# WebFrameWorkedWith      Which of the following web frameworks have you...
# WebFrameDesireNextYear  Which of the following web frameworks have you...
# UnitTests               Does your company regularly employ unit tests ...
# UndergradMajor          What was your main or most important field of ...
# ...

# %%
#sort index
schema_df.sort_index(inplace=True)
schema_df
# Out:
#                                                              QuestionText
# Column
# Age                     What is your age (in years)? If you prefer not...
# Age1stCode              At what age did you write your first line of c...
# BetterLife              Do you think people born today will have a bet...
# BlockchainIs            Blockchain / cryptocurrency technology is prim...
# BlockchainOrg           How is your organization thinking about or imp...
# CareerSat               Overall, how satisfied are you with your caree...
# CodeRev                          Do you review code as part of your work?
# CodeRevHrs              On average, how many hours per week do you spe...
# CompFreq                 Is that compensation weekly, monthly, or yearly?
# CompTotal               What is your current total compensation (salar...
# Containers              How do you use containers (Docker, Open Contai...
# ConvertedComp           Salary converted to annual USD salaries using ...
# ...

# %% [markdown]
# Filtering : Using Conditionals to Filter Rows and Columns

# %%
high_salary = (data_frame['ConvertedComp'] > 7000)

data_frame.loc[high_salary, ['Country', 'LanguageWorkedWith','ConvertedComp']]
# Out:
#                   Country                                 LanguageWorkedWith  \
# Respondent
# 3                Thailand                                           HTML/CSS
# 4           United States                                C;C++;C#;Python;SQL
# 6                  Canada                                         Java;R;SQL
# 9             New Zealand  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 10                  India                      C#;Go;JavaScript;Python;R;SQL
# ...                   ...                                                ...
# 88878       United States               HTML/CSS;JavaScript;Scala;TypeScript
# 88879             Finland                   Bash/Shell/PowerShell;C++;Python
# 88881             Austria  Bash/Shell/PowerShell;Go;HTML/CSS;Java;JavaScr...
# 88882         Netherlands             C#;HTML/CSS;Java;JavaScript;PHP;Python
# 88883              Greece              Go;HTML/CSS;Java;JavaScript;Other(s):
#
#             ConvertedComp
# ...

# %%
countires = ['United States', 'India', 'United Kingdom', 'Germany', 'Canada']
filt = (data_frame['Country'].isin(countires))
data_frame.loc[filt, 'Country']
# Out:
# Respondent
# 1        United Kingdom
# 4         United States
# 6                Canada
# 8                 India
# 10                India
#               ...
# 85642     United States
# 85961    United Kingdom
# 86012             India
# 88282     United States
# 88377            Canada
# Name: Country, Length: 45008, dtype: object

# %%
filt = data_frame['LanguageWorkedWith'].str.contains('Shell', na=False)
data_frame.loc[filt, 'LanguageWorkedWith']
# Out:
# Respondent
# 8        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 9        Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 12        Bash/Shell/PowerShell;HTML/CSS;Java;Python;R;SQL
# 13       Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 15       Assembly;Bash/Shell/PowerShell;C;C++;HTML/CSS;...
#                                ...
# 86012        Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript
# 86566      Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
# 87386    Assembly;Bash/Shell/PowerShell;C;C#;HTML/CSS;J...
# 88282    Bash/Shell/PowerShell;Go;HTML/CSS;JavaScript;W...
# 88863    Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# Name: LanguageWorkedWith, Length: 31991, dtype: object

# %% [markdown]
# Updating Cols and Rows

# %%
data_frame.rename(columns = {'ConvertedComp': 'SalaryUSD'}, inplace = True)
data_frame
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
data_frame['Hobbyist'].map({'Yes':True, 'No':False})
# Out:
# Respondent
# 1         True
# 2        False
# 3         True
# 4        False
# 5         True
#          ...
# 88377     True
# 88601    False
# 88802    False
# 88816    False
# 88863     True
# Name: Hobbyist, Length: 88883, dtype: bool

# %%
# almost the same work. but if it had any other value than yes and no and we don't want to touch the other values we use "replace"
data_frame['Hobbyist'] = data_frame['Hobbyist'].replace({'Yes':True, 'No':False})
data_frame['Hobbyist']
# Out:
# C:\Users\wq\AppData\Local\Temp\ipykernel_12352\2184206205.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data_frame['Hobbyist'] = data_frame['Hobbyist'].replace({'Yes':True, 'No':False})
# Respondent
# 1         True
# 2        False
# 3         True
# 4        False
# 5         True
#          ...
# 88377     True
# 88601    False
# 88802    False
# 88816    False
# 88863     True
# Name: Hobbyist, Length: 88883, dtype: bool

# %% [markdown]
# Sort

# %%
# sort dataframe by the countries
data_frame.sort_values(by='Country',inplace=True)
data_frame[['Country', 'SalaryUSD']].head()
# Out:
#                 Country  SalaryUSD
# Respondent
# 39258       Afghanistan    19152.0
# 63129       Afghanistan  1000000.0
# 85715       Afghanistan        NaN
# 50767       Afghanistan        NaN
# 2782        Afghanistan        NaN

# %%
# sort Country in ascending order and SalaryUSD in descending order
data_frame[['Country', 'SalaryUSD']].sort_values(by=['Country', 'SalaryUSD'], ascending=[True, False])
# Out:
#                 Country  SalaryUSD
# Respondent
# 63129       Afghanistan  1000000.0
# 50499       Afghanistan   153216.0
# 39258       Afghanistan    19152.0
# 58450       Afghanistan    17556.0
# 7085        Afghanistan    14364.0
# ...                 ...        ...
# 88062               NaN        NaN
# 88076               NaN        NaN
# 88601               NaN        NaN
# 88802               NaN        NaN
# 88816               NaN        NaN
#
# [88883 rows x 2 columns]

# %%
# give 10 largest salay:
data_frame['SalaryUSD'].nlargest(10)
# Out:
# Respondent
# 25983    2000000.0
# 87896    2000000.0
# 22013    2000000.0
# 28243    2000000.0
# 72732    2000000.0
# 78151    2000000.0
# 80200    2000000.0
# 52132    2000000.0
# 75561    2000000.0
# 32250    2000000.0
# Name: SalaryUSD, dtype: float64

# %%
# give 10 rows that have largest salary
data_frame.nlargest(10, 'SalaryUSD')
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 25983                          I am a developer by profession      True
# 87896                          I am a developer by profession      True
# 22013                          I am a developer by profession      True
# 28243                          I am a developer by profession      True
# 72732       I am not primarily a developer, but I write co...     False
# 78151                          I am a developer by profession      True
# 80200                          I am a developer by profession      True
# 52132                          I am a developer by profession      True
# 75561                          I am a developer by profession      True
# 32250                          I am a developer by profession      True
#
#                                                   OpenSourcer  \
# Respondent
# 25983                                 Less than once per year
# ...

# %%
# give 10 rows that have smallest salary
data_frame.nsmallest(10, 'SalaryUSD')
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 28638                          I am a developer by profession      True
# 722                            I am a developer by profession     False
# 13825                          I am a developer by profession      True
# 40913                          I am a developer by profession      True
# 30630                          I am a developer by profession      True
# 69049                          I am a developer by profession     False
# 19340       I am not primarily a developer, but I write co...      True
# 16214       I am not primarily a developer, but I write co...      True
# 29355                          I am a developer by profession      True
# 1685                           I am a developer by profession      True
#
#                                                   OpenSourcer  \
# Respondent
# 28638       Less than once a month but more than once per ...
# ...

# %%
data_frame.sort_index(inplace=True)

# %% [markdown]
# Grouping Data

# %%
data_frame['SalaryUSD'].head(15)
# Out:
# Respondent
# 1          NaN
# 2          NaN
# 3       8820.0
# 4      61000.0
# 5          NaN
# 6     366420.0
# 7          NaN
# 8          NaN
# 9      95179.0
# 10     13293.0
# 11         NaN
# 12         NaN
# 13     90000.0
# 14     57060.0
# 15         NaN
# Name: SalaryUSD, dtype: float64

# %%
# median:
data_frame['SalaryUSD'].median()
# Out:
# 57287.0

# %%
# count, mean, std, min, ... 
data_frame.describe()
# Out:
#           CompTotal     SalaryUSD   WorkWeekHrs    CodeRevHrs           Age
# count  5.594500e+04  5.582300e+04  64503.000000  49790.000000  79210.000000
# mean   5.519014e+11  1.271107e+05     42.127197      5.084308     30.336699
# std    7.331926e+13  2.841523e+05     37.287610      5.513931      9.178390
# min    0.000000e+00  0.000000e+00      1.000000      0.000000      1.000000
# 25%    2.000000e+04  2.577750e+04     40.000000      2.000000     24.000000
# 50%    6.200000e+04  5.728700e+04     40.000000      4.000000     29.000000
# 75%    1.200000e+05  1.000000e+05     44.750000      6.000000     35.000000
# max    1.000000e+16  2.000000e+06   4850.000000     99.000000     99.000000

# %%
# count: number of non-NaN (non-missing) rows
data_frame['SalaryUSD'].count()
# Out:
# 55823

# %%
# number of every value in Hobbyist
data_frame['Hobbyist'].value_counts()
# Out:
# Hobbyist
# True     71257
# False    17626
# Name: count, dtype: int64

# %%
# show by percentage
data_frame['SocialMedia'].value_counts(normalize=True)
# Out:
# SocialMedia
# Reddit                      0.170233
# YouTube                     0.163791
# WhatsApp                    0.158071
# Facebook                    0.156069
# Twitter                     0.134988
# Instagram                   0.074150
# I don't use social media    0.065777
# LinkedIn                    0.053306
# WeChat 微信                   0.007899
# Snapchat                    0.007437
# VK ВКонта́кте               0.007141
# Weibo 新浪微博                  0.000663
# Youku Tudou 优酷              0.000249
# Hello                       0.000225
# Name: proportion, dtype: float64

# %%
data_frame['Country'].value_counts()
# Out:
# Country
# United States        20949
# India                 9061
# Germany               5866
# United Kingdom        5737
# Canada                3395
#                      ...
# Tonga                    1
# Timor-Leste              1
# North Korea              1
# Brunei Darussalam        1
# Chad                     1
# Name: count, Length: 179, dtype: int64

# %%
# group dataframe by countries
country_grp = data_frame.groupby(['Country'])
country_grp.get_group('United States')
# Out:
# C:\Users\wq\AppData\Local\Temp\ipykernel_12352\91454453.py:3: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   country_grp.get_group('United States')
#                                                    MainBranch  Hobbyist  \
# Respondent
# 4                              I am a developer by profession     False
# 13                             I am a developer by profession      True
# 22                             I am a developer by profession      True
# 23                             I am a developer by profession      True
# 26                             I am a developer by profession      True
# ...                                                       ...       ...
# 88875       I used to be a developer by profession, but no...      True
# 88876                          I am a developer by profession      True
# ...

# %%
country_grp['SocialMedia'].value_counts().head(50)
# Out:
# Country              SocialMedia
# Afghanistan          Facebook                     15
#                      YouTube                       9
#                      I don't use social media      6
#                      WhatsApp                      4
#                      Instagram                     1
#                      LinkedIn                      1
#                      Twitter                       1
# Albania              WhatsApp                     18
#                      Facebook                     16
#                      Instagram                    13
#                      YouTube                      10
#                      Twitter                       8
#                      LinkedIn                      7
#                      Reddit                        6
#                      I don't use social media      4
#                      Snapchat                      1
#                      WeChat 微信                     1
# ...

# %%
# show popular social media in United Kingdom
country_grp['SocialMedia'].value_counts(normalize=True).loc['United Kingdom']
# Out:
# SocialMedia
# Reddit                      0.216192
# Twitter                     0.179409
# WhatsApp                    0.163902
# Facebook                    0.146232
# YouTube                     0.122791
# I don't use social media    0.067075
# Instagram                   0.057339
# LinkedIn                    0.031554
# Snapchat                    0.012622
# WeChat 微信                   0.001983
# VK ВКонта́кте               0.000541
# Weibo 新浪微博                  0.000180
# Youku Tudou 优酷              0.000180
# Name: proportion, dtype: float64

# %%
# same as:
flt = data_frame['Country'] == 'United Kingdom'
data_frame.loc[flt]['SocialMedia'].value_counts()
# Out:
# SocialMedia
# Reddit                      1199
# Twitter                      995
# WhatsApp                     909
# Facebook                     811
# YouTube                      681
# I don't use social media     372
# Instagram                    318
# LinkedIn                     175
# Snapchat                      70
# WeChat 微信                     11
# VK ВКонта́кте                  3
# Weibo 新浪微博                     1
# Youku Tudou 优酷                 1
# Name: count, dtype: int64

# %%
# avrage salary in every counrty
country_grp['SalaryUSD'].mean()
# Out:
# Country
# Afghanistan                             101953.333333
# Albania                                  21833.700000
# Algeria                                  34924.047619
# Andorra                                 160931.000000
# Angola                                    7764.000000
#                                             ...
# Venezuela, Bolivarian Republic of...     14581.627907
# Viet Nam                                 17233.436782
# Yemen                                    16909.166667
# Zambia                                   10075.375000
# Zimbabwe                                 34046.666667
# Name: SalaryUSD, Length: 179, dtype: float64

# %%
# avrage salary in Yemen
country_grp['SalaryUSD'].mean().loc['Yemen']
# Out:
# 16909.166666666668

# %%
country_grp['SalaryUSD'].agg(['median', 'mean'])
# Out:
#                                         median           mean
# Country
# Afghanistan                             6222.0  101953.333333
# Albania                                10818.0   21833.700000
# Algeria                                 7878.0   34924.047619
# Andorra                               160931.0  160931.000000
# Angola                                  7764.0    7764.000000
# ...                                        ...            ...
# Venezuela, Bolivarian Republic of...    6384.0   14581.627907
# Viet Nam                               11892.0   17233.436782
# Yemen                                  11940.0   16909.166667
# Zambia                                  5040.0   10075.375000
# Zimbabwe                               19200.0   34046.666667
#
# [179 rows x 2 columns]

# %%
country_grp['SalaryUSD'].agg(['median', 'mean']).loc['Canada']
# Out:
# median     68705.000000
# mean      134018.564909
# Name: Canada, dtype: float64

# %%
# number of people who live in India and they have worked with python
flt = data_frame['Country'] == 'India'
data_frame.loc[flt]['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 3105

# %%
country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
# what % of people from each country know python?
country_respondents = data_frame['Country'].value_counts()
country_respondents
# Out:
# Country
# United States        20949
# India                 9061
# Germany               5866
# United Kingdom        5737
# Canada                3395
#                      ...
# Tonga                    1
# Timor-Leste              1
# North Korea              1
# Brunei Darussalam        1
# Chad                     1
# Name: count, Length: 179, dtype: int64

# %%
country_uses_python = country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
country_uses_python
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
python_df = pd.concat([country_respondents, country_uses_python], axis='columns', sort=False)
python_df
# Out:
#                    count  LanguageWorkedWith
# Country
# United States      20949               10083
# India               9061                3105
# Germany             5866                2451
# United Kingdom      5737                2384
# Canada              3395                1558
# ...                  ...                 ...
# Tonga                  1                   0
# Timor-Leste            1                   1
# North Korea            1                   0
# Brunei Darussalam      1                   0
# Chad                   1                   0
#
# [179 rows x 2 columns]

# %%
python_df.rename(columns= {'count': 'NumRespondents', 'LanguageWorkedWith': 'NumKnowsPython'}, inplace=True)
python_df
# Out:
#                    NumRespondents  NumKnowsPython
# Country
# United States               20949           10083
# India                        9061            3105
# Germany                      5866            2451
# United Kingdom               5737            2384
# Canada                       3395            1558
# ...                           ...             ...
# Tonga                           1               0
# Timor-Leste                     1               1
# North Korea                     1               0
# Brunei Darussalam               1               0
# Chad                            1               0
#
# [179 rows x 2 columns]

# %%
# what % of people from each country know python?
python_df['PCTKnowsPython'] = (python_df['NumKnowsPython']/python_df['NumRespondents'])*100
python_df
# Out:
#                    NumRespondents  NumKnowsPython  PCTKnowsPython
# Country
# United States               20949           10083       48.131176
# India                        9061            3105       34.267741
# Germany                      5866            2451       41.783157
# United Kingdom               5737            2384       41.554820
# Canada                       3395            1558       45.891016
# ...                           ...             ...             ...
# Tonga                           1               0        0.000000
# Timor-Leste                     1               1      100.000000
# North Korea                     1               0        0.000000
# Brunei Darussalam               1               0        0.000000
# Chad                            1               0        0.000000
#
# [179 rows x 3 columns]

# %%
# sort 
python_df.sort_values(by='PCTKnowsPython', ascending=False,inplace=True)

# %%
python_df.head(50)
# Out:
#                                   NumRespondents  NumKnowsPython  \
# Country
# Sao Tome and Principe                          1               1
# Niger                                          1               1
# Timor-Leste                                    1               1
# Dominica                                       1               1
# Turkmenistan                                   7               6
# Mauritania                                     7               5
# Bahamas                                        3               2
# Guinea                                         3               2
# Guyana                                         3               2
# Uganda                                        72              47
# Iceland                                       49              30
# Namibia                                        5               3
# Benin                                          5               3
# ...

# %%
#
data_frame['YearsCode'] = data_frame['YearsCode'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[57], line 2
#       1 #
# ----> 2 data_frame['YearsCode'] = data_frame['YearsCode'].astype(float)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\generic.py:6637, in NDFrame.astype(self, dtype, copy, errors)
#    6631     results = [
#    6632         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6633     ]
#    6635 else:
#    6636     # else, only a single dtype is given
# -> 6637     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6638     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6639     return res.__finalize__(self, method="astype")
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\internals\managers.py:431, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
data_frame['YearsCode'].unique()
# Out:
# array(['4', nan, '3', '16', '13', '6', '8', '12', '2', '5', '17', '10',
#        '14', '35', '7', 'Less than 1 year', '30', '9', '26', '40', '19',
#        '15', '20', '28', '25', '1', '22', '11', '33', '50', '41', '18',
#        '34', '24', '23', '42', '27', '21', '36', '32', '39', '38', '31',
#        '37', 'More than 50 years', '29', '44', '45', '48', '46', '43',
#        '47', '49'], dtype=object)

# %%
data_frame['YearsCode'].replace('Less than 1 year', 0, inplace=True)
data_frame['YearsCode'].replace('More than 50 years', 51, inplace=True)

# %%
data_frame['YearsCode'].unique()
# Out:
# array(['4', nan, '3', '16', '13', '6', '8', '12', '2', '5', '17', '10',
#        '14', '35', '7', 0, '30', '9', '26', '40', '19', '15', '20', '28',
#        '25', '1', '22', '11', '33', '50', '41', '18', '34', '24', '23',
#        '42', '27', '21', '36', '32', '39', '38', '31', '37', 51, '29',
#        '44', '45', '48', '46', '43', '47', '49'], dtype=object)

# %%
data_frame['YearsCode'] = data_frame['YearsCode'].astype(float)

# %%
data_frame['YearsCode'].mean()
# Out:
# 11.662114216834588

# %%
data_frame['YearsCode'].median()

# %% [markdown]
# Reading/Writing Data to Different Sources - Excel, JSON, SQL,Etc

# %%
# write to a csv file 
flt = (data_frame['SalaryUSD'] >= 2000)
myDataFrame = data_frame.loc[flt]
myDataFrame.to_csv('Data/modified.csv')

# %%
# tsv
myDataFrame.to_csv('Data/modified.tsv', sep='\t')

# %%
# Excel
# instal these:
# pip install xlwt openpyxl xlrd

myDataFrame.to_excel('Data/modified.xlsx')

# %%
test = pd.read_excel('Data/modified.xlsx', index_col='Respondent')
test
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 3           I am not primarily a developer, but I write co...      True
# 4                              I am a developer by profession     False
# 6           I am not primarily a developer, but I write co...      True
# 9                              I am a developer by profession      True
# 10                             I am a developer by profession      True
# ...                                                       ...       ...
# 88878                          I am a developer by profession      True
# 88879                          I am a developer by profession      True
# 88881                          I am a developer by profession      True
# 88882                          I am a developer by profession      True
# 88883                          I am a developer by profession      True
#
#                            OpenSourcer  \
# Respondent
# ...

# %%
# JSON
# arguments are for more readable file
myDataFrame.to_json('Data/modified.json', orient='records', lines=True)

# %%
test = pd.read_json('Data/modified.json', orient='records', lines=True)
test
# Out:
#                                               MainBranch Hobbyist  \
# 0      I am not primarily a developer, but I write co...      Yes
# 1                         I am a developer by profession       No
# 2      I am not primarily a developer, but I write co...      Yes
# 3                         I am a developer by profession      Yes
# 4                         I am a developer by profession      Yes
# ...                                                  ...      ...
# 54910                     I am a developer by profession      Yes
# 54911                     I am a developer by profession      Yes
# 54912                     I am a developer by profession      Yes
# 54913                     I am a developer by profession      Yes
# 54914                     I am a developer by profession      Yes
#
#                       OpenSourcer  \
# 0                           Never
# 1                           Never
# 2                           Never
# ...
